# %%
print('h')
# Out:
# h

# %%
name='mahmoud'
age=21
course='machine learning'
print(f'name is {name},age is {age},course is {course}')
# Out:
# name is mahmoud,age is 21,course is machine learning

# %%
x=10
print(type(x))
# Out:
# <class 'int'>

# %%
list_1=[1,2,3,4,'depi','learning',True,[1,2,3,['ml','ai','genai']]]
list_1[7][3][1]
# Out:
# 'ai'

# %%
x='mahmoud'
list(x)
x.split()
# Out:
# ['mahmoud']
